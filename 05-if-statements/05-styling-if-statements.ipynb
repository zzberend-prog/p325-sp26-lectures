# %% [markdown]
# # If Statements
#
# Finally, let's talk about how to make your `if` statements stylish.
#
# ## Styling Your if Statements
#
# The only style recommendation PEP 8 provies for condition tests is to use a single space around comparison operators, such as `==`, `>=`, `<=`. For example:
# ```python
# if age < 4:
# ```
# is better than:
# ```python
# if age<4:
# ```
